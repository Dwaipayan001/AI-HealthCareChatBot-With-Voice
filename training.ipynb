# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# alembic                       1.6.5
# anyio                         3.3.0
# argon2-cffi                   20.1.0
# async-generator               1.10
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.1
# blinker                       1.4
# brotlipy                      0.7.0
# certifi                       2021.5.30
# certipy                       0.1.3
# cffi                          1.14.6
# chardet                       4.0.0
# charset-normalizer            2.0.0
# cloudpickle                   1.6.0
# contextvars                   2.4
# cryptography                  3.4.7
# cycler                        0.10.0
# Cython                        0.29.24
# cytoolz                       0.11.0
# dask                          2021.3.0
# dataclasses                   0.8
# decorator                     4.4.2
# defusedxml                    0.7.1
# entrypoints                   0.3
# gmpy2                         2.1.0b5
# greenlet                      1.1.0
# idna                          3.1
# imageio                       2.9.0
# immutables                    0.15
# importlib-metadata            4.6.3
# ipykernel                     5.5.5
# ipyparallel                   6.3.0
# ipython                       7.16.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.17.2
# Jinja2                        3.0.1
# joblib                        1.0.1
# json5                         0.9.5
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyter-offlinenotebook       0.2.1
# jupyter-resource-usage        0.6.0
# jupyter-server                1.10.1
# jupyter-telemetry             0.1.0
# jupyterhub                    1.4.2
# jupyterlab                    3.1.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.6.1
# jupyterlab-widgets            1.0.0
# kiwisolver                    1.3.1
# Mako                          1.1.4
# MarkupSafe                    2.0.1
# matplotlib                    3.3.4
# mistune                       0.8.4
# mpi4py                        3.1.1
# mpmath                        1.2.1
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.6.3
# notebook                      6.3.0
# nteract-on-jupyter            2.1.3
# numpy                         1.19.5
# oauthlib                      3.1.1
# olefile                       0.46
# packaging                     21.0
# pamela                        1.0.0
# pandas                        1.1.5
# pandocfilters                 1.4.2
# parso                         0.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.1
# pip                           21.2.2
# prometheus-client             0.11.0
# prompt-toolkit                3.0.19
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.9.0
# PyJWT                         2.1.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# PyQt5                         5.12.3
# PyQt5_sip                     4.19.18
# PyQtChart                     5.12
# PyQtWebEngine                 5.12.1
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# PyWavelets                    1.1.1
# PyYAML                        5.4.1
# pyzmq                         22.1.0
# requests                      2.26.0
# requests-unixsocket           0.2.0
# ruamel.yaml                   0.17.10
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.17.2
# scikit-learn                  0.24.2
# scipy                         1.5.3
# Send2Trash                    1.7.1
# setuptools                    49.6.0.post20210108
# six                           1.16.0
# sniffio                       1.2.0
# SQLAlchemy                    1.4.22
# sympy                         1.8
# terminado                     0.10.1
# testpath                      0.5.0
# threadpoolctl                 2.2.0
# tifffile                      2020.10.1
# toolz                         0.11.1
# tornado                       6.1
# traitlets                     4.3.3
# typing-extensions             3.10.0.0
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.57.0
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# zipp                          3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.6.2-cp36-cp36m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 7.7 kB/s eta 0:00:01     |█████████                       | 128.3 MB 3.0 MB/s eta 0:01:52MB 3.3 MB/s eta 0:00:42    |█████████████████████████████▎  | 418.9 MB 2.9 MB/s eta 0:00:14457.7 MB 3.8 MB/s eta 0:00:01
# Collecting grpcio<2.0,>=1.37.0
#   Downloading grpcio-1.42.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 70.3 MB/s eta 0:00:01
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 31.4 MB/s eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 701 kB/s  eta 0:00:01
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.4 MB/s  eta 0:00:01
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: wheel~=0.35 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorflow) (0.36.2)
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 30.5 MB/s eta 0:00:01
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 52.1 MB/s eta 0:00:01
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 50.5 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 70.4 MB/s eta 0:00:01
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy~=1.19.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 2.9 MB/s  eta 0:00:01
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 31.7 MB/s eta 0:00:01
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (49.6.0.post20210108)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 56.1 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 45.0 MB/s eta 0:00:01
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 64.1 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 43.1 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.26.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.9 MB/s  eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 70.8 MB/s eta 0:00:01
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.5.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s  eta 0:00:01
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.1.1)
# Requirement already satisfied: dataclasses in /srv/conda/envs/notebook/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow) (0.8)
# Building wheels for collected packages: clang, termcolor, wrapt
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30702 sha256=d589f4d5da0b3713c604dce8bb5b79d61d7bd6e61595c3123003b6fdf97508d1
#   Stored in directory: /home/jovyan/.cache/pip/wheels/22/4c/94/0583f60c9c5b6024ed64f290cb2d43b06bb4f75577dc3c93a7
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=48e05a0eacd7c63393c11c6409d976aba52e615ecfdc79a9bbac24e64830df44
#   Stored in directory: /home/jovyan/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69650 sha256=d01bb4d65dd89ca21224c68b501159c3b7cfa51fc18acf9e9a399ce70bcc11ab
#   Stored in directory: /home/jovyan/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built clang termcolor wrapt
# Installing collected packages: pyasn1, typing-extensions, six, rsa, pyasn1-modules, cachetools, requests-oauthlib, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, cached-property, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.0
#     Uninstalling typing-extensions-3.10.0.0:
#       Successfully uninstalled typing-extensions-3.10.0.0
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
# Successfully installed absl-py-0.15.0 astunparse-1.6.3 cached-property-1.5.2 cachetools-4.2.4 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.42.0 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.6 opt-einsum-3.3.0 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.8 six-1.15.0 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.6.2 tensorflow-estimator-2.6.0 termcolor-1.1.0 typing-extensions-3.7.4.3 werkzeug-2.0.2 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pickle
pip install json
# Out:
#   File "<ipython-input-1-3224c5e4d877>", line 1
#     pip install pickle
#               ^
# SyntaxError: invalid syntax

# %%
pip install pickle json
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.6.5-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 17.0 MB/s eta 0:00:01
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.6/site-packages (from nltk) (1.0.1)
# Collecting click
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.7 MB/s  eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 3.1 MB/s  eta 0:00:01
# Collecting regex>=2021.8.3
#   Downloading regex-2021.11.10-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (748 kB)
#      |████████████████████████████████| 748 kB 66.2 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.6/site-packages (from click->nltk) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata->click->nltk) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata->click->nltk) (3.7.4.3)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.0.3 nltk-3.6.5 regex-2021.11.10 tqdm-4.62.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.15.0
# alembic                       1.6.5
# anyio                         3.3.0
# argon2-cffi                   20.1.0
# astunparse                    1.6.3
# async-generator               1.10
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.1
# blinker                       1.4
# brotlipy                      0.7.0
# cached-property               1.5.2
# cachetools                    4.2.4
# certifi                       2021.5.30
# certipy                       0.1.3
# cffi                          1.14.6
# chardet                       4.0.0
# charset-normalizer            2.0.0
# clang                         5.0
# click                         8.0.3
# cloudpickle                   1.6.0
# contextvars                   2.4
# cryptography                  3.4.7
# cycler                        0.10.0
# Cython                        0.29.24
# cytoolz                       0.11.0
# dask                          2021.3.0
# dataclasses                   0.8
# decorator                     4.4.2
# defusedxml                    0.7.1
# entrypoints                   0.3
# flatbuffers                   1.12
# gast                          0.4.0
# gmpy2                         2.1.0b5
# google-auth                   1.35.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# greenlet                      1.1.0
# grpcio                        1.42.0
# h5py                          3.1.0
# idna                          3.1
# imageio                       2.9.0
# immutables                    0.15
# importlib-metadata            4.6.3
# ipykernel                     5.5.5
# ipyparallel                   6.3.0
# ipython                       7.16.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.17.2
# Jinja2                        3.0.1
# joblib                        1.0.1
# json5                         0.9.5
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyter-offlinenotebook       0.2.1
# jupyter-resource-usage        0.6.0
# jupyter-server                1.10.1
# jupyter-telemetry             0.1.0
# jupyterhub                    1.4.2
# jupyterlab                    3.1.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.6.1
# jupyterlab-widgets            1.0.0
# keras                         2.6.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.1
# Mako                          1.1.4
# Markdown                      3.3.6
# MarkupSafe                    2.0.1
# matplotlib                    3.3.4
# mistune                       0.8.4
# mpi4py                        3.1.1
# mpmath                        1.2.1
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.6.3
# nltk                          3.6.5
# notebook                      6.3.0
# nteract-on-jupyter            2.1.3
# numpy                         1.19.5
# oauthlib                      3.1.1
# olefile                       0.46
# opt-einsum                    3.3.0
# packaging                     21.0
# pamela                        1.0.0
# pandas                        1.1.5
# pandocfilters                 1.4.2
# parso                         0.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.1
# pip                           21.2.2
# prometheus-client             0.11.0
# prompt-toolkit                3.0.19
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.9.0
# PyJWT                         2.1.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# PyQt5                         5.12.3
# PyQt5_sip                     4.19.18
# PyQtChart                     5.12
# PyQtWebEngine                 5.12.1
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# PyWavelets                    1.1.1
# PyYAML                        5.4.1
# pyzmq                         22.1.0
# regex                         2021.11.10
# requests                      2.26.0
# requests-oauthlib             1.3.0
# requests-unixsocket           0.2.0
# rsa                           4.8
# ruamel.yaml                   0.17.10
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.17.2
# scikit-learn                  0.24.2
# scipy                         1.5.3
# Send2Trash                    1.7.1
# setuptools                    49.6.0.post20210108
# six                           1.15.0
# sniffio                       1.2.0
# SQLAlchemy                    1.4.22
# sympy                         1.8
# tensorboard                   2.6.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.6.2
# tensorflow-estimator          2.6.0
# termcolor                     1.1.0
# terminado                     0.10.1
# testpath                      0.5.0
# threadpoolctl                 2.2.0
# tifffile                      2020.10.1
# toolz                         0.11.1
# tornado                       6.1
# tqdm                          4.62.3
# traitlets                     4.3.3
# typing-extensions             3.7.4.3
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.57.0
# Werkzeug                      2.0.2
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# wrapt                         1.12.1
# zipp                          3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import json
import pickle

import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.optimizers import SGD

import numpy as np

# %%
lemmatizer = WordNetLemmatizer()

intents = json.loads(open("intents.json").read())

words = []
classes = []
documents = []

ignore_letters = ["?","!",".",","]

for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list,intent["tag"]))

        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.15.0
# alembic                       1.6.5
# anyio                         3.3.0
# argon2-cffi                   20.1.0
# astunparse                    1.6.3
# async-generator               1.10
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.1
# blinker                       1.4
# brotlipy                      0.7.0
# cached-property               1.5.2
# cachetools                    4.2.4
# certifi                       2021.5.30
# certipy                       0.1.3
# cffi                          1.14.6
# chardet                       4.0.0
# charset-normalizer            2.0.0
# clang                         5.0
# click                         8.0.3
# cloudpickle                   1.6.0
# contextvars                   2.4
# cryptography                  3.4.7
# cycler                        0.10.0
# Cython                        0.29.24
# cytoolz                       0.11.0
# dask                          2021.3.0
# dataclasses                   0.8
# decorator                     4.4.2
# defusedxml                    0.7.1
# entrypoints                   0.3
# flatbuffers                   1.12
# gast                          0.4.0
# gmpy2                         2.1.0b5
# google-auth                   1.35.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# greenlet                      1.1.0
# grpcio                        1.42.0
# h5py                          3.1.0
# idna                          3.1
# imageio                       2.9.0
# immutables                    0.15
# importlib-metadata            4.6.3
# ipykernel                     5.5.5
# ipyparallel                   6.3.0
# ipython                       7.16.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.17.2
# Jinja2                        3.0.1
# joblib                        1.0.1
# json5                         0.9.5
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyter-offlinenotebook       0.2.1
# jupyter-resource-usage        0.6.0
# jupyter-server                1.10.1
# jupyter-telemetry             0.1.0
# jupyterhub                    1.4.2
# jupyterlab                    3.1.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.6.1
# jupyterlab-widgets            1.0.0
# keras                         2.6.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.1
# Mako                          1.1.4
# Markdown                      3.3.6
# MarkupSafe                    2.0.1
# matplotlib                    3.3.4
# mistune                       0.8.4
# mpi4py                        3.1.1
# mpmath                        1.2.1
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.6.3
# nltk                          3.6.5
# notebook                      6.3.0
# nteract-on-jupyter            2.1.3
# numpy                         1.19.5
# oauthlib                      3.1.1
# olefile                       0.46
# opt-einsum                    3.3.0
# packaging                     21.0
# pamela                        1.0.0
# pandas                        1.1.5
# pandocfilters                 1.4.2
# parso                         0.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.1
# pip                           21.2.2
# prometheus-client             0.11.0
# prompt-toolkit                3.0.19
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.9.0
# PyJWT                         2.1.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# PyQt5                         5.12.3
# PyQt5_sip                     4.19.18
# PyQtChart                     5.12
# PyQtWebEngine                 5.12.1
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# PyWavelets                    1.1.1
# PyYAML                        5.4.1
# pyzmq                         22.1.0
# regex                         2021.11.10
# requests                      2.26.0
# requests-oauthlib             1.3.0
# requests-unixsocket           0.2.0
# rsa                           4.8
# ruamel.yaml                   0.17.10
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.17.2
# scikit-learn                  0.24.2
# scipy                         1.5.3
# Send2Trash                    1.7.1
# setuptools                    49.6.0.post20210108
# six                           1.15.0
# sniffio                       1.2.0
# SQLAlchemy                    1.4.22
# sympy                         1.8
# tensorboard                   2.6.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.6.2
# tensorflow-estimator          2.6.0
# termcolor                     1.1.0
# terminado                     0.10.1
# testpath                      0.5.0
# threadpoolctl                 2.2.0
# tifffile                      2020.10.1
# toolz                         0.11.1
# tornado                       6.1
# tqdm                          4.62.3
# traitlets                     4.3.3
# typing-extensions             3.7.4.3
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.57.0
# Werkzeug                      2.0.2
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# wrapt                         1.12.1
# zipp                          3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
words = sorted(set(words))
print(words)
# Out:
# ['Bye', 'Day', 'Good', 'Goodbye', 'Greetings', 'Hello', 'Hey', 'Hi', 'See', 'Thank', 'You', 'blackhead', 'confusion', 'coughing', 'eye', 'face', 'focus', 'forgetful', 'hyperactivity', 'impulsivity', 'itchy', 'judgement', 'lack', 'messy', 'neck', 'nose', 'of', 'pimple', 'poor', 'restlessness', 'shoulder', 'sneezing', 'time', 'watery', 'with', 'work', 'you']

# %%
classes = sorted(set(classes))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
training = []
output_empty = [0]*len(classes)

for document in documents:
    bag = []
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
        
    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag,output_row])
    
random.shuffle(training)
training = np.array(training)

train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
model = Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))


sgd = SGD(learning_rate=0.01,decay=1e-6,momentum=0.9,nesterov=True)
model.compile(loss='categorical_crossentropy',optimizer=sgd,metrics=['accuracy'])

hist = model.fit(np.array(train_x),np.array(train_y), epochs=200,batch_size=5,verbose=1)

model.save("chatbot_model.h5",hist)
print("Done!")
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.8443 - accuracy: 0.1538
# Epoch 2/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.7265 - accuracy: 0.1923
# Epoch 3/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.7181 - accuracy: 0.2308
# Epoch 4/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.6476 - accuracy: 0.3846
# Epoch 5/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.5237 - accuracy: 0.3077
# Epoch 6/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.5561 - accuracy: 0.2692
# Epoch 7/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.4292 - accuracy: 0.4615
# Epoch 8/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.4544 - accuracy: 0.5385
# Epoch 9/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.3559 - accuracy: 0.4615
# Epoch 10/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.2499 - accuracy: 0.5000
# Epoch 11/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.2927 - accuracy: 0.5385
# Epoch 12/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.2620 - accuracy: 0.5769
# Epoch 13/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.1504 - accuracy: 0.6538
# Epoch 14/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.1925 - accuracy: 0.6923
# Epoch 15/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1086 - accuracy: 0.7308
# Epoch 16/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1132 - accuracy: 0.6923
# Epoch 17/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1.0152 - accuracy: 0.7308
# Epoch 18/200
# 6/6 [==============================] - 0s 1ms/step - loss: 1.0710 - accuracy: 0.6923
# Epoch 19/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.9178 - accuracy: 0.8077
# Epoch 20/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.9801 - accuracy: 0.7308
# Epoch 21/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.8843 - accuracy: 0.8077
# Epoch 22/200
# 6/6 [==============================] - ETA: 0s - loss: 1.1016 - accuracy: 0.60 - 0s 1ms/step - loss: 0.9059 - accuracy: 0.7308
# Epoch 23/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.9424 - accuracy: 0.6923
# Epoch 24/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8415 - accuracy: 0.8462
# Epoch 25/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7972 - accuracy: 0.8846
# Epoch 26/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7803 - accuracy: 0.8077
# Epoch 27/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6561 - accuracy: 0.8846
# Epoch 28/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6288 - accuracy: 0.8846
# Epoch 29/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6390 - accuracy: 0.8077
# Epoch 30/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6241 - accuracy: 0.8077
# Epoch 31/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6355 - accuracy: 0.8462
# Epoch 32/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5436 - accuracy: 0.8846
# Epoch 33/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5867 - accuracy: 0.8846
# Epoch 34/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3836 - accuracy: 0.9615
# Epoch 35/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6036 - accuracy: 0.8846
# Epoch 36/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.4663 - accuracy: 0.9615
# Epoch 37/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4299 - accuracy: 0.9615
# Epoch 38/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.9615
# Epoch 39/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.4543 - accuracy: 0.9231
# Epoch 40/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.4498 - accuracy: 0.8462
# Epoch 41/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3896 - accuracy: 0.9231
# Epoch 42/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2464 - accuracy: 0.9615
# Epoch 43/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3553 - accuracy: 0.9231
# Epoch 44/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.4203 - accuracy: 0.9231
# Epoch 45/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2809 - accuracy: 0.9615
# Epoch 46/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.8846
# Epoch 47/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3105 - accuracy: 0.9231
# Epoch 48/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2913 - accuracy: 0.9231
# Epoch 49/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3111 - accuracy: 0.9615
# Epoch 50/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3548 - accuracy: 0.9231
# Epoch 51/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2905 - accuracy: 0.9231
# Epoch 52/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8846
# Epoch 53/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3117 - accuracy: 0.9615
# Epoch 54/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3397 - accuracy: 0.9231
# Epoch 55/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2605 - accuracy: 0.9615
# Epoch 56/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9615
# Epoch 57/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3341 - accuracy: 0.9231
# Epoch 58/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2302 - accuracy: 0.9615
# Epoch 59/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2675 - accuracy: 0.9615
# Epoch 60/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2800 - accuracy: 0.9615
# Epoch 61/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1830 - accuracy: 0.9615
# Epoch 62/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2034 - accuracy: 0.9615
# Epoch 63/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3183 - accuracy: 0.9231
# Epoch 64/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2755 - accuracy: 0.9615
# Epoch 65/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2882 - accuracy: 0.9615
# Epoch 66/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2555 - accuracy: 0.9615
# Epoch 67/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1969 - accuracy: 0.9615
# Epoch 68/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2493 - accuracy: 0.9231
# Epoch 69/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2593 - accuracy: 0.8846
# Epoch 70/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1624 - accuracy: 0.9615
# Epoch 71/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2319 - accuracy: 0.9231
# Epoch 72/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1304 - accuracy: 0.9615
# Epoch 73/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2449 - accuracy: 0.9615
# Epoch 74/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2230 - accuracy: 0.9231
# Epoch 75/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.8846
# Epoch 76/200
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2853 - accuracy: 0.8077
# Epoch 77/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2451 - accuracy: 0.8846
# Epoch 78/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2131 - accuracy: 0.9615
# Epoch 79/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2969 - accuracy: 0.9615
# Epoch 80/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2761 - accuracy: 0.9615
# Epoch 81/200
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2159 - accuracy: 0.9615
# Epoch 82/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.9615
# Epoch 83/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.9615
# Epoch 84/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2008 - accuracy: 0.9231
# Epoch 85/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2194 - accuracy: 0.9615
# Epoch 86/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1478 - accuracy: 0.9615
# Epoch 87/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.9231
# Epoch 88/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.9231
# Epoch 89/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1699 - accuracy: 0.9615
# Epoch 90/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2517 - accuracy: 0.9231
# Epoch 91/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2210 - accuracy: 0.9615
# Epoch 92/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1931 - accuracy: 0.9615
# Epoch 93/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1504 - accuracy: 0.9231
# Epoch 94/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1720 - accuracy: 0.9615
# Epoch 95/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2154 - accuracy: 0.9615
# Epoch 96/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1245 - accuracy: 0.9615
# Epoch 97/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1773 - accuracy: 0.9615
# Epoch 98/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9615
# Epoch 99/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9615
# Epoch 100/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1750 - accuracy: 0.9615
# Epoch 101/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2187 - accuracy: 0.9231
# Epoch 102/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.8846
# Epoch 103/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1466 - accuracy: 0.9615
# Epoch 104/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.9231
# Epoch 105/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1474 - accuracy: 0.9231
# Epoch 106/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9615
# Epoch 107/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2908 - accuracy: 0.9231
# Epoch 108/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1238 - accuracy: 0.9615
# Epoch 109/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.8462
# Epoch 110/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1246 - accuracy: 0.9615
# Epoch 111/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3005 - accuracy: 0.8846
# Epoch 112/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9615
# Epoch 113/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.9615
# Epoch 114/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2787 - accuracy: 0.8846
# Epoch 115/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1466 - accuracy: 0.9615
# Epoch 116/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9231
# Epoch 117/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1906 - accuracy: 0.8462
# Epoch 118/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1272 - accuracy: 0.9615
# Epoch 119/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2416 - accuracy: 0.9231
# Epoch 120/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1148 - accuracy: 0.9615
# Epoch 121/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1700 - accuracy: 0.9615
# Epoch 122/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2019 - accuracy: 0.9615
# Epoch 123/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1646 - accuracy: 0.9231
# Epoch 124/200
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2006 - accuracy: 0.9615
# Epoch 125/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1574 - accuracy: 0.9615
# Epoch 126/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9615
# Epoch 127/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2314 - accuracy: 0.8846
# Epoch 128/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1732 - accuracy: 0.9615
# Epoch 129/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9615
# Epoch 130/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1593 - accuracy: 0.9615
# Epoch 131/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2350 - accuracy: 0.9231
# Epoch 132/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9615
# Epoch 133/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2002 - accuracy: 0.9615
# Epoch 134/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1677 - accuracy: 0.9231
# Epoch 135/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1605 - accuracy: 0.9615
# Epoch 136/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9615
# Epoch 137/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.9615
# Epoch 138/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1472 - accuracy: 0.9231
# Epoch 139/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9615
# Epoch 140/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1446 - accuracy: 0.9615
# Epoch 141/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9615
# Epoch 142/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1612 - accuracy: 0.9615
# Epoch 143/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1503 - accuracy: 0.9615
# Epoch 144/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2538 - accuracy: 0.8846
# Epoch 145/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1311 - accuracy: 0.9231
# Epoch 146/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0962 - accuracy: 0.9615
# Epoch 147/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1607 - accuracy: 0.9615
# Epoch 148/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1160 - accuracy: 0.9615
# Epoch 149/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1462 - accuracy: 0.9615
# Epoch 150/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1526 - accuracy: 0.9615
# Epoch 151/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1036 - accuracy: 0.9615
# Epoch 152/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2241 - accuracy: 0.9231
# Epoch 153/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1912 - accuracy: 0.9615
# Epoch 154/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1980 - accuracy: 0.9231
# Epoch 155/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9615
# Epoch 156/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1324 - accuracy: 0.9615
# Epoch 157/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1340 - accuracy: 0.9615
# Epoch 158/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1495 - accuracy: 0.9615
# Epoch 159/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1953 - accuracy: 0.9231
# Epoch 160/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1209 - accuracy: 0.9615
# Epoch 161/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1121 - accuracy: 0.9615
# Epoch 162/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1456 - accuracy: 0.9615
# Epoch 163/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1322 - accuracy: 0.9615
# Epoch 164/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1533 - accuracy: 0.9615
# Epoch 165/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.9231
# Epoch 166/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2587 - accuracy: 0.9231
# Epoch 167/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1710 - accuracy: 0.9231
# Epoch 168/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9615
# Epoch 169/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1522 - accuracy: 0.9615
# Epoch 170/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1516 - accuracy: 0.9615
# Epoch 171/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1470 - accuracy: 0.9615
# Epoch 172/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1522 - accuracy: 0.9615
# Epoch 173/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1783 - accuracy: 0.9615
# Epoch 174/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1673 - accuracy: 0.9615
# Epoch 175/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1457 - accuracy: 0.9615
# Epoch 176/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1247 - accuracy: 0.9615
# Epoch 177/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9615
# Epoch 178/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1284 - accuracy: 0.9615
# Epoch 179/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0891 - accuracy: 0.9615
# Epoch 180/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1278 - accuracy: 0.9615
# Epoch 181/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1382 - accuracy: 0.9615
# Epoch 182/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1317 - accuracy: 0.9615
# Epoch 183/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1200 - accuracy: 0.9615
# Epoch 184/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1171 - accuracy: 0.9615
# Epoch 185/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1419 - accuracy: 0.9615
# Epoch 186/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.9615
# Epoch 187/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1214 - accuracy: 0.9231
# Epoch 188/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1534 - accuracy: 0.9615
# Epoch 189/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1306 - accuracy: 0.9615
# Epoch 190/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1231 - accuracy: 0.9615
# Epoch 191/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1647 - accuracy: 0.9615
# Epoch 192/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0969 - accuracy: 0.9615
# Epoch 193/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1750 - accuracy: 0.9231
# Epoch 194/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9615
# Epoch 195/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1696 - accuracy: 0.9615
# Epoch 196/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1024 - accuracy: 0.9615
# Epoch 197/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.9231
# Epoch 198/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1180 - accuracy: 0.9615
# Epoch 199/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.9615
# Epoch 200/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1298 - accuracy: 0.9231
# Done!
