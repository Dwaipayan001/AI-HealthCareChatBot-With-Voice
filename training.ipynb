# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# alembic                       1.6.5
# anyio                         3.3.0
# argon2-cffi                   20.1.0
# async-generator               1.10
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.1
# blinker                       1.4
# brotlipy                      0.7.0
# certifi                       2021.5.30
# certipy                       0.1.3
# cffi                          1.14.6
# chardet                       4.0.0
# charset-normalizer            2.0.0
# cloudpickle                   1.6.0
# contextvars                   2.4
# cryptography                  3.4.7
# cycler                        0.10.0
# Cython                        0.29.24
# cytoolz                       0.11.0
# dask                          2021.3.0
# dataclasses                   0.8
# decorator                     4.4.2
# defusedxml                    0.7.1
# entrypoints                   0.3
# gmpy2                         2.1.0b5
# greenlet                      1.1.0
# idna                          3.1
# imageio                       2.9.0
# immutables                    0.15
# importlib-metadata            4.6.3
# ipykernel                     5.5.5
# ipyparallel                   6.3.0
# ipython                       7.16.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.17.2
# Jinja2                        3.0.1
# joblib                        1.0.1
# json5                         0.9.5
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyter-offlinenotebook       0.2.1
# jupyter-resource-usage        0.6.0
# jupyter-server                1.10.1
# jupyter-telemetry             0.1.0
# jupyterhub                    1.4.2
# jupyterlab                    3.1.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.6.1
# jupyterlab-widgets            1.0.0
# kiwisolver                    1.3.1
# Mako                          1.1.4
# MarkupSafe                    2.0.1
# matplotlib                    3.3.4
# mistune                       0.8.4
# mpi4py                        3.1.1
# mpmath                        1.2.1
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.6.3
# notebook                      6.3.0
# nteract-on-jupyter            2.1.3
# numpy                         1.19.5
# oauthlib                      3.1.1
# olefile                       0.46
# packaging                     21.0
# pamela                        1.0.0
# pandas                        1.1.5
# pandocfilters                 1.4.2
# parso                         0.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.1
# pip                           21.2.2
# prometheus-client             0.11.0
# prompt-toolkit                3.0.19
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.9.0
# PyJWT                         2.1.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# PyQt5                         5.12.3
# PyQt5_sip                     4.19.18
# PyQtChart                     5.12
# PyQtWebEngine                 5.12.1
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# PyWavelets                    1.1.1
# PyYAML                        5.4.1
# pyzmq                         22.1.0
# requests                      2.26.0
# requests-unixsocket           0.2.0
# ruamel.yaml                   0.17.10
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.17.2
# scikit-learn                  0.24.2
# scipy                         1.5.3
# Send2Trash                    1.7.1
# setuptools                    49.6.0.post20210108
# six                           1.16.0
# sniffio                       1.2.0
# SQLAlchemy                    1.4.22
# sympy                         1.8
# terminado                     0.10.1
# testpath                      0.5.0
# threadpoolctl                 2.2.0
# tifffile                      2020.10.1
# toolz                         0.11.1
# tornado                       6.1
# traitlets                     4.3.3
# typing-extensions             3.10.0.0
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.57.0
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# zipp                          3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.6.2-cp36-cp36m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 7.7 kB/s eta 0:00:01     |█████████                       | 128.3 MB 3.0 MB/s eta 0:01:52MB 3.3 MB/s eta 0:00:42    |█████████████████████████████▎  | 418.9 MB 2.9 MB/s eta 0:00:14457.7 MB 3.8 MB/s eta 0:00:01
# Collecting grpcio<2.0,>=1.37.0
#   Downloading grpcio-1.42.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 70.3 MB/s eta 0:00:01
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 31.4 MB/s eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 701 kB/s  eta 0:00:01
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.4 MB/s  eta 0:00:01
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: wheel~=0.35 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorflow) (0.36.2)
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 30.5 MB/s eta 0:00:01
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 52.1 MB/s eta 0:00:01
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 50.5 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 70.4 MB/s eta 0:00:01
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy~=1.19.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 2.9 MB/s  eta 0:00:01
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 31.7 MB/s eta 0:00:01
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (49.6.0.post20210108)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 56.1 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 45.0 MB/s eta 0:00:01
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 64.1 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 43.1 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.26.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.9 MB/s  eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 70.8 MB/s eta 0:00:01
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.5.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s  eta 0:00:01
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.1.1)
# Requirement already satisfied: dataclasses in /srv/conda/envs/notebook/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow) (0.8)
# Building wheels for collected packages: clang, termcolor, wrapt
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30702 sha256=d589f4d5da0b3713c604dce8bb5b79d61d7bd6e61595c3123003b6fdf97508d1
#   Stored in directory: /home/jovyan/.cache/pip/wheels/22/4c/94/0583f60c9c5b6024ed64f290cb2d43b06bb4f75577dc3c93a7
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=48e05a0eacd7c63393c11c6409d976aba52e615ecfdc79a9bbac24e64830df44
#   Stored in directory: /home/jovyan/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69650 sha256=d01bb4d65dd89ca21224c68b501159c3b7cfa51fc18acf9e9a399ce70bcc11ab
#   Stored in directory: /home/jovyan/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built clang termcolor wrapt
# Installing collected packages: pyasn1, typing-extensions, six, rsa, pyasn1-modules, cachetools, requests-oauthlib, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, cached-property, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.0
#     Uninstalling typing-extensions-3.10.0.0:
#       Successfully uninstalled typing-extensions-3.10.0.0
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
# Successfully installed absl-py-0.15.0 astunparse-1.6.3 cached-property-1.5.2 cachetools-4.2.4 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.42.0 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.6 opt-einsum-3.3.0 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.8 six-1.15.0 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.6.2 tensorflow-estimator-2.6.0 termcolor-1.1.0 typing-extensions-3.7.4.3 werkzeug-2.0.2 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pickle
pip install json
# Out:
#   File "<ipython-input-1-3224c5e4d877>", line 1
#     pip install pickle
#               ^
# SyntaxError: invalid syntax

# %%
pip install pickle json
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.6.5-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 17.0 MB/s eta 0:00:01
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.6/site-packages (from nltk) (1.0.1)
# Collecting click
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.7 MB/s  eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 3.1 MB/s  eta 0:00:01
# Collecting regex>=2021.8.3
#   Downloading regex-2021.11.10-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (748 kB)
#      |████████████████████████████████| 748 kB 66.2 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.6/site-packages (from click->nltk) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata->click->nltk) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata->click->nltk) (3.7.4.3)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.0.3 nltk-3.6.5 regex-2021.11.10 tqdm-4.62.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.15.0
# alembic                       1.6.5
# anyio                         3.3.0
# argon2-cffi                   20.1.0
# astunparse                    1.6.3
# async-generator               1.10
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.1
# blinker                       1.4
# brotlipy                      0.7.0
# cached-property               1.5.2
# cachetools                    4.2.4
# certifi                       2021.5.30
# certipy                       0.1.3
# cffi                          1.14.6
# chardet                       4.0.0
# charset-normalizer            2.0.0
# clang                         5.0
# click                         8.0.3
# cloudpickle                   1.6.0
# contextvars                   2.4
# cryptography                  3.4.7
# cycler                        0.10.0
# Cython                        0.29.24
# cytoolz                       0.11.0
# dask                          2021.3.0
# dataclasses                   0.8
# decorator                     4.4.2
# defusedxml                    0.7.1
# entrypoints                   0.3
# flatbuffers                   1.12
# gast                          0.4.0
# gmpy2                         2.1.0b5
# google-auth                   1.35.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# greenlet                      1.1.0
# grpcio                        1.42.0
# h5py                          3.1.0
# idna                          3.1
# imageio                       2.9.0
# immutables                    0.15
# importlib-metadata            4.6.3
# ipykernel                     5.5.5
# ipyparallel                   6.3.0
# ipython                       7.16.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.17.2
# Jinja2                        3.0.1
# joblib                        1.0.1
# json5                         0.9.5
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyter-offlinenotebook       0.2.1
# jupyter-resource-usage        0.6.0
# jupyter-server                1.10.1
# jupyter-telemetry             0.1.0
# jupyterhub                    1.4.2
# jupyterlab                    3.1.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.6.1
# jupyterlab-widgets            1.0.0
# keras                         2.6.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.1
# Mako                          1.1.4
# Markdown                      3.3.6
# MarkupSafe                    2.0.1
# matplotlib                    3.3.4
# mistune                       0.8.4
# mpi4py                        3.1.1
# mpmath                        1.2.1
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.6.3
# nltk                          3.6.5
# notebook                      6.3.0
# nteract-on-jupyter            2.1.3
# numpy                         1.19.5
# oauthlib                      3.1.1
# olefile                       0.46
# opt-einsum                    3.3.0
# packaging                     21.0
# pamela                        1.0.0
# pandas                        1.1.5
# pandocfilters                 1.4.2
# parso                         0.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.1
# pip                           21.2.2
# prometheus-client             0.11.0
# prompt-toolkit                3.0.19
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.9.0
# PyJWT                         2.1.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# PyQt5                         5.12.3
# PyQt5_sip                     4.19.18
# PyQtChart                     5.12
# PyQtWebEngine                 5.12.1
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# PyWavelets                    1.1.1
# PyYAML                        5.4.1
# pyzmq                         22.1.0
# regex                         2021.11.10
# requests                      2.26.0
# requests-oauthlib             1.3.0
# requests-unixsocket           0.2.0
# rsa                           4.8
# ruamel.yaml                   0.17.10
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.17.2
# scikit-learn                  0.24.2
# scipy                         1.5.3
# Send2Trash                    1.7.1
# setuptools                    49.6.0.post20210108
# six                           1.15.0
# sniffio                       1.2.0
# SQLAlchemy                    1.4.22
# sympy                         1.8
# tensorboard                   2.6.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.6.2
# tensorflow-estimator          2.6.0
# termcolor                     1.1.0
# terminado                     0.10.1
# testpath                      0.5.0
# threadpoolctl                 2.2.0
# tifffile                      2020.10.1
# toolz                         0.11.1
# tornado                       6.1
# tqdm                          4.62.3
# traitlets                     4.3.3
# typing-extensions             3.7.4.3
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.57.0
# Werkzeug                      2.0.2
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# wrapt                         1.12.1
# zipp                          3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import json
import pickle

import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.optimizers import SGD

import numpy as np
# Out:
# 2022-08-24 03:49:37.212428: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
lemmatizer = WordNetLemmatizer()

intents = json.loads(open("intents.json").read())

words = []
classes = []
documents = []

ignore_letters = ["?","!",".",","]

for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list,intent["tag"]))

        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.15.0
# alembic                       1.6.5
# anyio                         3.3.0
# argon2-cffi                   20.1.0
# astunparse                    1.6.3
# async-generator               1.10
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.1
# blinker                       1.4
# brotlipy                      0.7.0
# cached-property               1.5.2
# cachetools                    4.2.4
# certifi                       2021.5.30
# certipy                       0.1.3
# cffi                          1.14.6
# chardet                       4.0.0
# charset-normalizer            2.0.0
# clang                         5.0
# click                         8.0.3
# cloudpickle                   1.6.0
# contextvars                   2.4
# cryptography                  3.4.7
# cycler                        0.10.0
# Cython                        0.29.24
# cytoolz                       0.11.0
# dask                          2021.3.0
# dataclasses                   0.8
# decorator                     4.4.2
# defusedxml                    0.7.1
# entrypoints                   0.3
# flatbuffers                   1.12
# gast                          0.4.0
# gmpy2                         2.1.0b5
# google-auth                   1.35.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# greenlet                      1.1.0
# grpcio                        1.42.0
# h5py                          3.1.0
# idna                          3.1
# imageio                       2.9.0
# immutables                    0.15
# importlib-metadata            4.6.3
# ipykernel                     5.5.5
# ipyparallel                   6.3.0
# ipython                       7.16.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.17.2
# Jinja2                        3.0.1
# joblib                        1.0.1
# json5                         0.9.5
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyter-offlinenotebook       0.2.1
# jupyter-resource-usage        0.6.0
# jupyter-server                1.10.1
# jupyter-telemetry             0.1.0
# jupyterhub                    1.4.2
# jupyterlab                    3.1.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.6.1
# jupyterlab-widgets            1.0.0
# keras                         2.6.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.1
# Mako                          1.1.4
# Markdown                      3.3.6
# MarkupSafe                    2.0.1
# matplotlib                    3.3.4
# mistune                       0.8.4
# mpi4py                        3.1.1
# mpmath                        1.2.1
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.6.3
# nltk                          3.6.5
# notebook                      6.3.0
# nteract-on-jupyter            2.1.3
# numpy                         1.19.5
# oauthlib                      3.1.1
# olefile                       0.46
# opt-einsum                    3.3.0
# packaging                     21.0
# pamela                        1.0.0
# pandas                        1.1.5
# pandocfilters                 1.4.2
# parso                         0.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.1
# pip                           21.2.2
# prometheus-client             0.11.0
# prompt-toolkit                3.0.19
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.9.0
# PyJWT                         2.1.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# PyQt5                         5.12.3
# PyQt5_sip                     4.19.18
# PyQtChart                     5.12
# PyQtWebEngine                 5.12.1
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# PyWavelets                    1.1.1
# PyYAML                        5.4.1
# pyzmq                         22.1.0
# regex                         2021.11.10
# requests                      2.26.0
# requests-oauthlib             1.3.0
# requests-unixsocket           0.2.0
# rsa                           4.8
# ruamel.yaml                   0.17.10
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.17.2
# scikit-learn                  0.24.2
# scipy                         1.5.3
# Send2Trash                    1.7.1
# setuptools                    49.6.0.post20210108
# six                           1.15.0
# sniffio                       1.2.0
# SQLAlchemy                    1.4.22
# sympy                         1.8
# tensorboard                   2.6.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.6.2
# tensorflow-estimator          2.6.0
# termcolor                     1.1.0
# terminado                     0.10.1
# testpath                      0.5.0
# threadpoolctl                 2.2.0
# tifffile                      2020.10.1
# toolz                         0.11.1
# tornado                       6.1
# tqdm                          4.62.3
# traitlets                     4.3.3
# typing-extensions             3.7.4.3
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.57.0
# Werkzeug                      2.0.2
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# wrapt                         1.12.1
# zipp                          3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/rumbleftw/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/rumbleftw/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words = sorted(set(words))
print(words)
# Out:
# ['Bye', 'Day', 'Good', 'Goodbye', 'Greetings', 'Hello', 'Hey', 'Hi', 'See', 'Severe', 'Thank', 'You', 'a', 'abnormal', 'about', 'ache', 'aching', 'affected', 'all', 'amount', 'and', 'anxiety', 'anxious', 'appetite', 'area', 'arm', 'at', 'back', 'bad', 'be', 'beat', 'before', 'being', 'belching', 'belly', 'blackhead', 'bladder', 'block', 'blocked', 'blood', 'blood-stained', 'blue', 'blurry', 'body', 'breath', 'breathing', 'breathlessness', 'bulk', 'burning', 'ca', 'change', 'chest', 'chesty', 'chill', 'choking', 'clear', 'coating', 'cold', 'coming', 'complex', 'concentrating', 'concentration', 'confused', 'confusion', 'constantly', 'constipation', 'continuous', 'control', 'cough', 'coughing', 'cramp', 'dark', 'death', 'decreased', 'delayed', 'delusional', 'depressed', 'diarrhoea', 'difficult', 'difficulty', 'discoloured', 'distortion', 'disturbance', 'disturbed', 'dizziness', 'drowsy', 'dry', 'ear', 'easily', 'eat', 'eating', 'energy', 'esteem', 'event', 'everything', 'excessive', 'exhaustion', 'experienced', 'expression', 'eye', 'eyelid', 'face', 'facial', 'failure', 'fainting', 'faintness', 'falling', 'fast', 'fatigue', 'fear', 'feel', 'feeling', 'fever', 'finger', 'fluttering', 'focus', 'food', 'foot', 'forgetful', 'form', 'frequent', 'frequently', 'full', 'fullness', 'gaining', 'gas', 'gasping', 'goodbye', 'gray', 'growth', 'guilty', 'gum', 'habit', 'hair', 'hand', 'hard', 'have', 'having', 'headache', 'heal', 'hearing', 'heart', 'heartbeat', 'heavy', 'heel', 'helpless', 'hip', 'hoarse', 'hopeless', 'hot', 'hurt', 'hyper', 'hyperactivity', 'image', 'impulsivity', 'in', 'inconsistency', 'infected', 'infrequent', 'intense', 'interest', 'into', 'inwards', 'irregular', 'irritated', 'is', 'it', 'itchy', 'jaundice', 'jaw', 'jerking', 'joint', 'joy', 'judgement', 'lack', 'lacking', 'language', 'large', 'lash', 'learning', 'leg', 'light', 'light-headedness', 'like', 'limb', 'lip', 'little', 'losing', 'loss', 'loud', 'low', 'lower', 'make', 'messy', 'mood', 'motion', 'motivation', 'mouth', 'move', 'movement', 'muscle', 'my', "n't", 'nail', 'navel', 'near', 'neck', 'need', 'night', 'nighttime', 'no', 'nose', 'numbness', 'o', 'occasionally', 'odor', 'of', 'off', 'on', 'or', 'out', 'over', 'overeats', 'pain', 'pale', 'palpitation', 'part', 'passing', 'peeing', 'pelvic', 'persistent', 'pessimistic', 'phlegm', 'pimple', 'poor', 'posture', 'pounding', 'pressure', 'problem', 'proper', 'rapid', 'rapidly', 'red', 'redness', 'reduced', 'restlessness', 'ringing', 'rubbing', 'runny', 'sadness', 'say', 'seizure', 'self', 'sensation', 'sense', 'sensitive', 'sensitivity', 'severe', 'shadow', 'shaking', 'shortness', 'shoulder', 'skin', 'sleep', 'sleeping', 'slower', 'slowly', 'smacking', 'smell', 'sneezing', 'snoring', 'something', 'sore', 'sored', 'sound', 'spasm', 'speaking', 'speech', 'spread', 'sticky', 'stiff', 'stiffness', 'stomach', 'stop', 'stuffy', 'sudden', 'suicidal', 'swallowing', 'sweating', 'sweaty', 'swelling', 'swollen', 'taste', 'temperature', 'temporary', 'tender', 'terrifies', 'than', 'the', 'thing', 'think', 'thinking', 'thirsty', 'thought', 'throat', 'through', 'tight', 'tightness', 'time', 'tingling', 'tinted', 'tired', 'tiredness', 'to', 'tongue', 'tooth', 'trouble', 'turning', 'twisted', 'unable', 'under', 'underweight', 'unusual', 'up', 'upset', 'urinate', 'urine', 'usual', 'very', 'vision', 'voice', 'vomiting', 'vowel', 'wake', 'walking', 'watery', 'weakness', 'weight', 'wheezing', 'with', 'word', 'work', 'worried', 'worthless', 'wound', 'yellow', 'yellowish', 'you']

# %%
classes = sorted(set(classes))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
training = []
output_empty = [0]*len(classes)

for document in documents:
    bag = []
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
        
    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag,output_row])
    
random.shuffle(training)
training = np.array(training)

train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# /tmp/ipykernel_6599/1083640328.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %%
model = Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))


sgd = SGD(learning_rate=0.01,decay=1e-6,momentum=0.9,nesterov=True)
model.compile(loss='categorical_crossentropy',optimizer=sgd,metrics=['accuracy'])

hist = model.fit(np.array(train_x),np.array(train_y), epochs=200,batch_size=5,verbose=1)

model.save("chatbot_model.h5",hist)
print("Done!")
# Out:
# Epoch 1/200
# 56/56 [==============================] - 1s 3ms/step - loss: 3.9212 - accuracy: 0.0314
# Epoch 2/200
# 56/56 [==============================] - 0s 3ms/step - loss: 3.8589 - accuracy: 0.0093
# Epoch 3/200
# 56/56 [==============================] - 0s 2ms/step - loss: 3.8320 - accuracy: 0.0447
# Epoch 4/200
# 56/56 [==============================] - 0s 2ms/step - loss: 3.8074 - accuracy: 0.0592
# Epoch 5/200
# 56/56 [==============================] - 0s 3ms/step - loss: 3.7843 - accuracy: 0.1008
# Epoch 6/200
# 56/56 [==============================] - 0s 2ms/step - loss: 3.7328 - accuracy: 0.0648
# Epoch 7/200
# 56/56 [==============================] - 0s 2ms/step - loss: 3.6836 - accuracy: 0.0900
# Epoch 8/200
# 56/56 [==============================] - 0s 3ms/step - loss: 3.5867 - accuracy: 0.1117
# Epoch 9/200
# 56/56 [==============================] - 0s 5ms/step - loss: 3.5676 - accuracy: 0.0987
# Epoch 10/200
# 56/56 [==============================] - 0s 5ms/step - loss: 3.3964 - accuracy: 0.1349
# Epoch 11/200
# 56/56 [==============================] - 0s 5ms/step - loss: 3.4514 - accuracy: 0.1852
# Epoch 12/200
# 56/56 [==============================] - 0s 5ms/step - loss: 3.0800 - accuracy: 0.2050
# Epoch 13/200
# 56/56 [==============================] - 0s 5ms/step - loss: 3.0872 - accuracy: 0.1917
# Epoch 14/200
# 56/56 [==============================] - 0s 5ms/step - loss: 3.0023 - accuracy: 0.2923
# Epoch 15/200
# 56/56 [==============================] - 0s 5ms/step - loss: 2.8172 - accuracy: 0.2674
# Epoch 16/200
# 56/56 [==============================] - 0s 3ms/step - loss: 2.7007 - accuracy: 0.2932
# Epoch 17/200
# 56/56 [==============================] - 0s 2ms/step - loss: 2.6779 - accuracy: 0.2907
# Epoch 18/200
# 56/56 [==============================] - 0s 2ms/step - loss: 2.3842 - accuracy: 0.4131
# Epoch 19/200
# 56/56 [==============================] - 0s 4ms/step - loss: 2.2931 - accuracy: 0.4213
# Epoch 20/200
# 56/56 [==============================] - 0s 5ms/step - loss: 2.2843 - accuracy: 0.3802
# Epoch 21/200
# 56/56 [==============================] - 0s 5ms/step - loss: 2.1380 - accuracy: 0.4751
# Epoch 22/200
# 56/56 [==============================] - 0s 5ms/step - loss: 1.9346 - accuracy: 0.4974
# Epoch 23/200
# 56/56 [==============================] - 0s 5ms/step - loss: 1.8732 - accuracy: 0.5257
# Epoch 24/200
# 56/56 [==============================] - 0s 6ms/step - loss: 2.0680 - accuracy: 0.4280
# Epoch 25/200
# 56/56 [==============================] - 0s 8ms/step - loss: 1.9793 - accuracy: 0.4364
# Epoch 26/200
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6472 - accuracy: 0.5232
# Epoch 27/200
# 56/56 [==============================] - 1s 9ms/step - loss: 1.5718 - accuracy: 0.5315
# Epoch 28/200
# 56/56 [==============================] - 0s 8ms/step - loss: 1.5332 - accuracy: 0.5627
# Epoch 29/200
# 56/56 [==============================] - ETA: 0s - loss: 1.6584 - accuracy: 0.50 - 0s 8ms/step - loss: 1.6569 - accuracy: 0.5087
# Epoch 30/200
# 56/56 [==============================] - 0s 9ms/step - loss: 1.4467 - accuracy: 0.5971
# Epoch 31/200
# 56/56 [==============================] - 0s 7ms/step - loss: 1.4190 - accuracy: 0.5650
# Epoch 32/200
# 56/56 [==============================] - 0s 6ms/step - loss: 1.3639 - accuracy: 0.6128
# Epoch 33/200
# 56/56 [==============================] - 0s 6ms/step - loss: 1.3427 - accuracy: 0.5788
# Epoch 34/200
# 56/56 [==============================] - 0s 6ms/step - loss: 1.2008 - accuracy: 0.6409
# Epoch 35/200
# 56/56 [==============================] - 0s 6ms/step - loss: 1.3797 - accuracy: 0.6329
# Epoch 36/200
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1605 - accuracy: 0.6974
# Epoch 37/200
# 56/56 [==============================] - 0s 7ms/step - loss: 1.1884 - accuracy: 0.6554
# Epoch 38/200
# 56/56 [==============================] - 0s 7ms/step - loss: 1.1489 - accuracy: 0.6651
# Epoch 39/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.9735 - accuracy: 0.7204
# Epoch 40/200
# 56/56 [==============================] - 0s 6ms/step - loss: 1.0160 - accuracy: 0.7068
# Epoch 41/200
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1027 - accuracy: 0.6792
# Epoch 42/200
# 56/56 [==============================] - 0s 4ms/step - loss: 1.0326 - accuracy: 0.6955
# Epoch 43/200
# 56/56 [==============================] - 0s 6ms/step - loss: 1.0623 - accuracy: 0.6930: 0s - loss: 1.0870 - accuracy:
# Epoch 44/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.8413 - accuracy: 0.7708
# Epoch 45/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.9320 - accuracy: 0.6879
# Epoch 46/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.7980 - accuracy: 0.7799
# Epoch 47/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.8393 - accuracy: 0.7593
# Epoch 48/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.9298 - accuracy: 0.7296
# Epoch 49/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.7996 - accuracy: 0.7957
# Epoch 50/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.7757 - accuracy: 0.7814
# Epoch 51/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.7963 - accuracy: 0.7414
# Epoch 52/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.8400 - accuracy: 0.7525
# Epoch 53/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.8372 - accuracy: 0.7238
# Epoch 54/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.8461 - accuracy: 0.7462
# Epoch 55/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.7388 - accuracy: 0.8003
# Epoch 56/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.8469 - accuracy: 0.7332
# Epoch 57/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.8535 - accuracy: 0.7100
# Epoch 58/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.7996
# Epoch 59/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.8493 - accuracy: 0.7298
# Epoch 60/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.7060 - accuracy: 0.7695
# Epoch 61/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.8994 - accuracy: 0.7005
# Epoch 62/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6623 - accuracy: 0.7945
# Epoch 63/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6479 - accuracy: 0.8214
# Epoch 64/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5648 - accuracy: 0.8364
# Epoch 65/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.7302 - accuracy: 0.7432
# Epoch 66/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6201 - accuracy: 0.8175
# Epoch 67/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.7259 - accuracy: 0.7623
# Epoch 68/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6189 - accuracy: 0.8093
# Epoch 69/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6634 - accuracy: 0.7672
# Epoch 70/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6320 - accuracy: 0.7915
# Epoch 71/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6390 - accuracy: 0.7845
# Epoch 72/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6090 - accuracy: 0.8192
# Epoch 73/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5637 - accuracy: 0.8373
# Epoch 74/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.5426 - accuracy: 0.8153
# Epoch 75/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4478 - accuracy: 0.8686
# Epoch 76/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5790 - accuracy: 0.8281
# Epoch 77/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5191 - accuracy: 0.8089
# Epoch 78/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6067 - accuracy: 0.8066
# Epoch 79/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.6146 - accuracy: 0.7582
# Epoch 80/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6469 - accuracy: 0.7913
# Epoch 81/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5216 - accuracy: 0.8355
# Epoch 82/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6200 - accuracy: 0.7986
# Epoch 83/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.7870 - accuracy: 0.7830
# Epoch 84/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4966 - accuracy: 0.8449
# Epoch 85/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4926 - accuracy: 0.8475
# Epoch 86/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5668 - accuracy: 0.8137
# Epoch 87/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.7084 - accuracy: 0.7417
# Epoch 88/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5180 - accuracy: 0.8314
# Epoch 89/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4848 - accuracy: 0.8232
# Epoch 90/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5301 - accuracy: 0.8001
# Epoch 91/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5101 - accuracy: 0.8391
# Epoch 92/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4240 - accuracy: 0.8694
# Epoch 93/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5335 - accuracy: 0.8377
# Epoch 94/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5160 - accuracy: 0.8308
# Epoch 95/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5994 - accuracy: 0.8081
# Epoch 96/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4123 - accuracy: 0.8510
# Epoch 97/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4641 - accuracy: 0.8634
# Epoch 98/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4744 - accuracy: 0.8433
# Epoch 99/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.4909 - accuracy: 0.8435
# Epoch 100/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.6262 - accuracy: 0.8075
# Epoch 101/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6555 - accuracy: 0.7735
# Epoch 102/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4423 - accuracy: 0.8538
# Epoch 103/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4269 - accuracy: 0.8652
# Epoch 104/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.5673 - accuracy: 0.8332
# Epoch 105/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4084 - accuracy: 0.8711
# Epoch 106/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4379 - accuracy: 0.8558
# Epoch 107/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4747 - accuracy: 0.8242
# Epoch 108/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3595 - accuracy: 0.8597
# Epoch 109/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5195 - accuracy: 0.8279
# Epoch 110/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4880 - accuracy: 0.8334
# Epoch 111/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4787 - accuracy: 0.8419
# Epoch 112/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.5246 - accuracy: 0.7975
# Epoch 113/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4677 - accuracy: 0.8436
# Epoch 114/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.5125 - accuracy: 0.8064
# Epoch 115/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.5212 - accuracy: 0.8119
# Epoch 116/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4438 - accuracy: 0.8879
# Epoch 117/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.3725 - accuracy: 0.8624
# Epoch 118/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5877 - accuracy: 0.7922
# Epoch 119/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4759 - accuracy: 0.8240
# Epoch 120/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5535 - accuracy: 0.8065
# Epoch 121/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.3472 - accuracy: 0.8892
# Epoch 122/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4677 - accuracy: 0.8377
# Epoch 123/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4711 - accuracy: 0.8092
# Epoch 124/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5525 - accuracy: 0.8171
# Epoch 125/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4544 - accuracy: 0.8606
# Epoch 126/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4905 - accuracy: 0.8355
# Epoch 127/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4820 - accuracy: 0.8240
# Epoch 128/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.5088 - accuracy: 0.8430
# Epoch 129/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4643 - accuracy: 0.8317
# Epoch 130/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5351 - accuracy: 0.8459
# Epoch 131/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4756 - accuracy: 0.8015
# Epoch 132/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3759 - accuracy: 0.8552
# Epoch 133/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4064 - accuracy: 0.8687
# Epoch 134/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.5000 - accuracy: 0.8326: 0s - loss: 0.5499 - accura
# Epoch 135/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.3408 - accuracy: 0.8926
# Epoch 136/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.3862 - accuracy: 0.8098
# Epoch 137/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5690 - accuracy: 0.8270
# Epoch 138/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4878 - accuracy: 0.8321
# Epoch 139/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.3820 - accuracy: 0.8237
# Epoch 140/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3033 - accuracy: 0.9110
# Epoch 141/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4053 - accuracy: 0.8658
# Epoch 142/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4519 - accuracy: 0.8544
# Epoch 143/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4459 - accuracy: 0.8703
# Epoch 144/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5027 - accuracy: 0.8199
# Epoch 145/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5455 - accuracy: 0.8061
# Epoch 146/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4545 - accuracy: 0.8570
# Epoch 147/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4499 - accuracy: 0.8360
# Epoch 148/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4991 - accuracy: 0.8394
# Epoch 149/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4100 - accuracy: 0.8239
# Epoch 150/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4534 - accuracy: 0.8510
# Epoch 151/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4248 - accuracy: 0.8753
# Epoch 152/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.8472
# Epoch 153/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6151 - accuracy: 0.8040
# Epoch 154/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3663 - accuracy: 0.8590
# Epoch 155/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3651 - accuracy: 0.8727
# Epoch 156/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5348 - accuracy: 0.8418
# Epoch 157/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4713 - accuracy: 0.8429
# Epoch 158/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4187 - accuracy: 0.8703
# Epoch 159/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3534 - accuracy: 0.8583
# Epoch 160/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5006 - accuracy: 0.8144
# Epoch 161/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4484 - accuracy: 0.8199
# Epoch 162/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4021 - accuracy: 0.8521
# Epoch 163/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3947 - accuracy: 0.8854
# Epoch 164/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3458 - accuracy: 0.8829
# Epoch 165/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4414 - accuracy: 0.8468
# Epoch 166/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.5274 - accuracy: 0.8352
# Epoch 167/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4377 - accuracy: 0.8130
# Epoch 168/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4250 - accuracy: 0.8441
# Epoch 169/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4573 - accuracy: 0.8138
# Epoch 170/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4017 - accuracy: 0.8606
# Epoch 171/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4301 - accuracy: 0.8657
# Epoch 172/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4475 - accuracy: 0.8422
# Epoch 173/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3091 - accuracy: 0.8899
# Epoch 174/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3793 - accuracy: 0.8862
# Epoch 175/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4114 - accuracy: 0.8469
# Epoch 176/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3816 - accuracy: 0.8629
# Epoch 177/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3952 - accuracy: 0.8614
# Epoch 178/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.3829 - accuracy: 0.8610
# Epoch 179/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4003 - accuracy: 0.8760
# Epoch 180/200
# 56/56 [==============================] - 0s 7ms/step - loss: 0.4120 - accuracy: 0.8310
# Epoch 181/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3887 - accuracy: 0.8337
# Epoch 182/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3724 - accuracy: 0.8664
# Epoch 183/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4652 - accuracy: 0.8401
# Epoch 184/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4990 - accuracy: 0.8229
# Epoch 185/200
# 56/56 [==============================] - 0s 8ms/step - loss: 0.3068 - accuracy: 0.9094
# Epoch 186/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4107 - accuracy: 0.8618
# Epoch 187/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.4009 - accuracy: 0.8422
# Epoch 188/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5097 - accuracy: 0.8242
# Epoch 189/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3587 - accuracy: 0.8564
# Epoch 190/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.5019 - accuracy: 0.8350
# Epoch 191/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3786 - accuracy: 0.8712
# Epoch 192/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3946 - accuracy: 0.8673
# Epoch 193/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.3886 - accuracy: 0.8699
# Epoch 194/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.4412 - accuracy: 0.8445
# Epoch 195/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3879 - accuracy: 0.8510
# Epoch 196/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4810 - accuracy: 0.8372
# Epoch 197/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3109 - accuracy: 0.8699
# Epoch 198/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.2789 - accuracy: 0.9118
# Epoch 199/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.5197 - accuracy: 0.8257
# Epoch 200/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.4106 - accuracy: 0.8426
# Done!
